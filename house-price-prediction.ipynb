# %%
import warnings
warnings.simplefilter("ignore", FutureWarning)

# %%
import pandas as pd
url = "../House-Price-Prediction/House Price Prediction Dataset.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.nunique()
# Out:
# Area         1622
# Bedrooms        5
# Bathrooms       4
# Floors          3
# YearBuilt     124
# Location        4
# Condition       4
# Garage          2
# Price        1999
# dtype: int64

# %%
df.describe().T
# Out:
#             count         mean            std      min       25%       50%  \
# Area       2000.0    2786.2095    1295.146799    501.0    1653.0    2833.0
# Bedrooms   2000.0       3.0035       1.424606      1.0       2.0       3.0
# Bathrooms  2000.0       2.5525       1.108990      1.0       2.0       3.0
# Floors     2000.0       1.9935       0.809188      1.0       1.0       2.0
# YearBuilt  2000.0    1961.4460      35.926695   1900.0    1930.0    1961.0
# Price      2000.0  537676.8550  276428.845719  50005.0  300098.0  539254.0
#
#                 75%       max
# Area         3887.5    4999.0
# Bedrooms        4.0       5.0
# Bathrooms       4.0       4.0
# Floors          3.0       3.0
# YearBuilt    1993.0    2023.0
# Price      780086.0  999656.0

# %%
df = df.drop(columns=["Id"]) #ID is irrelevant as it has 2000 unique value for 2000 datasets

# %%
df.isnull().sum()
# Out:
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
df.hist(figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'Bedrooms'}>],
#        [<Axes: title={'center': 'Bathrooms'}>,
#         <Axes: title={'center': 'Floors'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)
